# %% [markdown]
# ## Combine Data

# %%
import os
import pandas as pd

# Directory containing the subfolders with sensor files
base_dir = 'data/raw'
combined_dir = 'data/combined'  # Directory to save combined sensor data

# Create the combined directory if it doesn’t exist
os.makedirs(combined_dir, exist_ok=True)

# Dictionary to hold data for each sensor
sensor_data = {}

# Traverse all folders and subfolders
for root, _, files in os.walk(base_dir):
    for file_name in files:
        # Check if the file is a CSV and matches the sensor pattern (e.g., 'Indoor01.csv')
        if file_name.endswith('.csv') and file_name.startswith('Indoor'):
            file_path = os.path.join(root, file_name)
            
            # Read the CSV file
            df = pd.read_csv(file_path)
            
            # Add the data to the sensor's list in the dictionary
            if file_name not in sensor_data:
                sensor_data[file_name] = []  # Initialize list for the sensor if not already present
            
            sensor_data[file_name].append(df)

# Combine and save each sensor's data
for sensor, dfs in sensor_data.items():
    if dfs:  # Check if there is any data to concatenate
        combined_sensor_data = pd.concat(dfs, ignore_index=True)
        
        # Save the combined data for each sensor in the 'combined' folder
        combined_file_path = os.path.join(combined_dir, sensor)
        combined_sensor_data.to_csv(combined_file_path, index=False)

# %% [markdown]
# ## Clean Data

# %%
# Directory containing sensor data files
data_dir = 'data/combined'
output_dir = 'data/filtered_raw' 

# Create the filtered directory if it doesn’t exist
os.makedirs(output_dir, exist_ok=True)

# Define the date ranges for each sensor based on the data provided
sensor_time_frames = {
    'Indoor01.csv': ('2024-02-14', '2024-04-16'), 
    'Indoor02.csv': ('2024-02-20', '2024-07-23'),
    'Indoor03.csv': ('2024-02-27', '2024-07-27'),
    'Indoor04.csv': ('2024-03-04', '2024-07-14'),
    'Indoor05.csv': ('2024-03-08', '2024-08-26'),
    'Indoor06.csv': ('2024-03-23', '2024-09-06'),
    'Indoor07.csv': ('2024-04-04', '2024-08-11'),
    'Indoor08.csv': ('2024-04-23', '2024-08-20'),
    'Indoor09.csv': ('2024-04-25', '2024-08-31'),
    'Indoor10.csv': ('2024-04-30', '2024-08-30'),
    'Indoor11.csv': ('2024-05-04', '2024-09-07'),
    'Indoor12.csv': ('2024-05-04', '2024-09-15'),
    'Indoor13.csv': ('2024-05-14', '2024-08-09'),  
    'Indoor14.csv': ('2024-05-25', '2024-10-09'),
    'Indoor15.csv': ('2024-07-14', '2024-10-09') 
}

# %%
# Define the columns that need to be converted to numeric
numeric_columns = ['PM 1.0', 'PM 2.5', 'PM 4.0', 'PM 10',
                   'NC 0.5', 'NC 1.0', 'NC 2.5', 'NC 10',
                   'CO2', 'Barometric Pressure', 'VOC tVOC measurement',
                   'VOC Ethanol', 'Temperature', 'Relative Humidity']

# Function to clean each sensor DataFrame
def clean_sensor_dataframe(sensor_df):
    # Remove header
    sensor_df = sensor_df.iloc[1:]
    # Sort by 'Timestamp' and reset index
    sensor_df = sensor_df.sort_values(by=['Timestamp']).reset_index(drop=True)
    # Convert 'Timestamp' column to datetime
    sensor_df['Timestamp'] = pd.to_datetime(sensor_df['Timestamp'], errors='coerce')
    # Convert specified columns to numeric, coerce errors to NaN
    sensor_df[numeric_columns] = sensor_df[numeric_columns].apply(pd.to_numeric, errors='coerce')
    return sensor_df

# Loop over each sensor file in the data directory
for file_name in os.listdir(data_dir):
    file_path = os.path.join(data_dir, file_name)
    
    # Check if the file is a CSV and in the sensor time frames dictionary
    if file_name.endswith('.csv') and file_name in sensor_time_frames:
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Clean the sensor DataFrame
        df = clean_sensor_dataframe(df)
        
        # Get the start and end date for this sensor
        start_date, end_date = sensor_time_frames[file_name]
        start_date = pd.to_datetime(start_date)
        
        # Apply date filtering based on the defined range
        if end_date:
            end_date = pd.to_datetime(end_date)
            filtered_df = df[(df['Timestamp'] >= start_date) & (df['Timestamp'] <= end_date)]
        else:
            filtered_df = df[df['Timestamp'] >= start_date]
        
        # Save the cleaned and filtered data to the output directory
        output_file_path = os.path.join(output_dir, file_name)
        filtered_df.to_csv(output_file_path, index=False)

# %% [markdown]
# ## Harmonization

# %%
# Directory containing filtered sensor data files
filtered_dir = 'data/filtered_raw'  # Directory with cleaned and filtered data
harmonized_dir = 'data/harmonized'  # Directory to save harmonized data
parameters_dir = "parameters"  # Directory containing individual parameter files

# Ensure the harmonized directory exists
os.makedirs(harmonized_dir, exist_ok=True)

# Define the columns to calibrate
working_columns = ['PM 2.5', 'CO2', 'Barometric Pressure', 'VOC tVOC measurement', 'Temperature', 'Relative Humidity']

# %%
# Loop through each dataset in the filtered directory
for file_name in os.listdir(filtered_dir):
    file_path = os.path.join(filtered_dir, file_name)
    
    # Process only CSV files
    if file_name.endswith('.csv'):
        # Read the filtered dataset
        sensor_df = pd.read_csv(file_path)
        
        # Use the filename (without extension) as the Sensor ID
        sensor_id = file_name.replace(".csv", "")  # e.g., 'Indoor01.csv' -> 'Indoor01'
        sensor_df['Sensor'] = sensor_id  # Add the Sensor ID to the DataFrame
        
        print(f"\nProcessing file: {file_name} with Sensor ID: {sensor_id}")

        # Loop through each column in working_columns to apply calibration
        for column_name in working_columns:
            # Prepare the path to the coefficients file
            coeff_file_name = f"{column_name.lower().replace(' ', '_')}_coefficients_df.csv"
            coefficients_file = os.path.join(parameters_dir, coeff_file_name)
            
            # Check if the coefficient file exists
            if os.path.exists(coefficients_file):
                # Read the coefficients data
                coefficients_df = pd.read_csv(coefficients_file)
                
                # Rename columns dynamically to avoid conflicts
                coefficients_df.rename(columns={'Coefficient': f'{column_name}_Coefficient',
                                                'Intercept': f'{column_name}_Intercept'}, inplace=True)
                
                # Merge the sensor DataFrame with the coefficients DataFrame
                sensor_df = pd.merge(sensor_df, coefficients_df, on='Sensor', how='left')
                
                # Check if the merge was successful by inspecting NaNs in coefficient columns
                if sensor_df[f'{column_name}_Coefficient'].isnull().all():
                    print(f"Warning: All coefficients missing for '{column_name}' in sensor '{sensor_id}'")
                else:
                    # Print out the first few rows to verify calibration before applying it
                    print(f"\nBefore calibration for '{column_name}':")
                    print(sensor_df[[column_name, f'{column_name}_Coefficient', f'{column_name}_Intercept']].head())

                    # Apply calibration formula
                    sensor_df[column_name] = sensor_df[column_name] * sensor_df[f'{column_name}_Coefficient'] + sensor_df[f'{column_name}_Intercept']
                    
                    # Check the first few calibrated values
                    print(f"\nCalibrated values for '{column_name}' in '{file_name}':")
                    print(sensor_df[[column_name]].head())
                
                # Drop coefficient and intercept columns to clean up
                sensor_df.drop(columns=[f'{column_name}_Coefficient', f'{column_name}_Intercept'], inplace=True)
            else:
                print(f"Warning: No coefficients file found for {coeff_file_name}")
        
        # Save the harmonized data to the harmonized directory
        harmonized_file_path = os.path.join(harmonized_dir, file_name)
        sensor_df.to_csv(harmonized_file_path, index=False)

print("All harmonized datasets have been saved.")
# Out:
# Processing file: Indoor14.csv with Sensor ID: Indoor14
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0     6.0            0.949117         -0.426889
# 1     6.0            0.949117         -0.426889
# 2     5.0            0.949117         -0.426889
# 3     4.0            0.949117         -0.426889
# 4     4.0            0.949117         -0.426889
#
# Calibrated values for 'PM 2.5' in 'Indoor14.csv':
#      PM 2.5
# 0  5.267815
# 1  5.267815
# 2  4.318698
# 3  3.369580
# 4  3.369580
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  441.0          0.95968      20.720851
# 1  446.0          0.95968      20.720851
# 2  446.0          0.95968      20.720851
# 3  446.0          0.95968      20.720851
# 4  437.0          0.95968      20.720851
#
# Calibrated values for 'CO2' in 'Indoor14.csv':
#           CO2
# 0  443.939767
# 1  448.738167
# 2  448.738167
# 3  448.738167
# 4  440.101046
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.61                         0.987145  \
# 1                23.61                         0.987145
# 2                23.61                         0.987145
# 3                23.61                         0.987145
# 4                23.60                         0.987145
#
#    Barometric Pressure_Intercept
# 0                       0.292873
# 1                       0.292873
# 2                       0.292873
# 3                       0.292873
# 4                       0.292873
#
# Calibrated values for 'Barometric Pressure' in 'Indoor14.csv':
#    Barometric Pressure
# 0            23.599357
# 1            23.599357
# 2            23.599357
# 3            23.599357
# 4            23.589485
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.394                           1.03789  \
# 1                 0.392                           1.03789
# 2                 0.381                           1.03789
# 3                 0.354                           1.03789
# 4                 0.321                           1.03789
#
#    VOC tVOC measurement_Intercept
# 0                        0.026271
# 1                        0.026271
# 2                        0.026271
# 3                        0.026271
# 4                        0.026271
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor14.csv':
#    VOC tVOC measurement
# 0              0.435200
# 1              0.433124
# 2              0.421707
# 3              0.393684
# 4              0.359434
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         70.5                 0.986584               0.856756
# 1         70.5                 0.986584               0.856756
# 2         70.5                 0.986584               0.856756
# 3         70.3                 0.986584               0.856756
# 4         70.3                 0.986584               0.856756
#
# Calibrated values for 'Temperature' in 'Indoor14.csv':
#    Temperature
# 0    70.410961
# 1    70.410961
# 2    70.410961
# 3    70.213644
# 4    70.213644
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               63.0                       1.031697  \
# 1               64.0                       1.031697
# 2               64.0                       1.031697
# 3               64.0                       1.031697
# 4               64.0                       1.031697
#
#    Relative Humidity_Intercept
# 0                    -1.366351
# 1                    -1.366351
# 2                    -1.366351
# 3                    -1.366351
# 4                    -1.366351
#
# Calibrated values for 'Relative Humidity' in 'Indoor14.csv':
#    Relative Humidity
# 0          63.630582
# 1          64.662279
# 2          64.662279
# 3          64.662279
# 4          64.662279
#
# Processing file: Indoor01.csv with Sensor ID: Indoor01
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0     5.0            2.508077         -0.051978
# 1     5.0            2.508077         -0.051978
# 2     4.0            2.508077         -0.051978
# 3     4.0            2.508077         -0.051978
# 4     4.0            2.508077         -0.051978
#
# Calibrated values for 'PM 2.5' in 'Indoor01.csv':
#       PM 2.5
# 0  12.488409
# 1  12.488409
# 2   9.980331
# 3   9.980331
# 4   9.980331
#
# Before calibration for 'CO2':
#       CO2  CO2_Coefficient  CO2_Intercept
# 0  1618.0          1.01035      -2.341322
# 1  1587.0          1.01035      -2.341322
# 2  1545.0          1.01035      -2.341322
# 3  1508.0          1.01035      -2.341322
# 4  1515.0          1.01035      -2.341322
#
# Calibrated values for 'CO2' in 'Indoor01.csv':
#            CO2
# 0  1632.405752
# 1  1601.084887
# 2  1558.650167
# 3  1521.267200
# 4  1528.339653
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.36                         0.997538  \
# 1                23.36                         0.997538
# 2                23.36                         0.997538
# 3                23.36                         0.997538
# 4                23.36                         0.997538
#
#    Barometric Pressure_Intercept
# 0                       0.087622
# 1                       0.087622
# 2                       0.087622
# 3                       0.087622
# 4                       0.087622
#
# Calibrated values for 'Barometric Pressure' in 'Indoor01.csv':
#    Barometric Pressure
# 0            23.390104
# 1            23.390104
# 2            23.390104
# 3            23.390104
# 4            23.390104
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.183                          0.908284  \
# 1                 0.148                          0.908284
# 2                 0.049                          0.908284
# 3                 0.005                          0.908284
# 4                 0.036                          0.908284
#
#    VOC tVOC measurement_Intercept
# 0                        0.008089
# 1                        0.008089
# 2                        0.008089
# 3                        0.008089
# 4                        0.008089
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor01.csv':
#    VOC tVOC measurement
# 0              0.174305
# 1              0.142515
# 2              0.052595
# 3              0.012630
# 4              0.040787
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         73.0                 0.965395               2.461006
# 1         73.0                 0.965395               2.461006
# 2         72.9                 0.965395               2.461006
# 3         72.7                 0.965395               2.461006
# 4         72.5                 0.965395               2.461006
#
# Calibrated values for 'Temperature' in 'Indoor01.csv':
#    Temperature
# 0    72.934844
# 1    72.934844
# 2    72.838305
# 3    72.645226
# 4    72.452147
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               59.0                       0.969444  \
# 1               59.0                       0.969444
# 2               59.0                       0.969444
# 3               59.0                       0.969444
# 4               59.0                       0.969444
#
#    Relative Humidity_Intercept
# 0                     1.905022
# 1                     1.905022
# 2                     1.905022
# 3                     1.905022
# 4                     1.905022
#
# Calibrated values for 'Relative Humidity' in 'Indoor01.csv':
#    Relative Humidity
# 0          59.102221
# 1          59.102221
# 2          59.102221
# 3          59.102221
# 4          59.102221
#
# Processing file: Indoor15.csv with Sensor ID: Indoor15
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    13.0            1.000337          0.115949
# 1    13.0            1.000337          0.115949
# 2    13.0            1.000337          0.115949
# 3    13.0            1.000337          0.115949
# 4    13.0            1.000337          0.115949
#
# Calibrated values for 'PM 2.5' in 'Indoor15.csv':
#      PM 2.5
# 0  13.12033
# 1  13.12033
# 2  13.12033
# 3  13.12033
# 4  13.12033
#
# Before calibration for 'CO2':
#        CO2  CO2_Coefficient  CO2_Intercept
# 0  15459.0         0.927056       35.47323
# 1  15463.0         0.927056       35.47323
# 2  15482.0         0.927056       35.47323
# 3  15479.0         0.927056       35.47323
# 4  15462.0         0.927056       35.47323
#
# Calibrated values for 'CO2' in 'Indoor15.csv':
#             CO2
# 0  14366.831308
# 1  14370.539532
# 2  14388.153595
# 3  14385.372428
# 4  14369.612476
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.64                         0.987023  \
# 1                23.64                         0.987023
# 2                23.64                         0.987023
# 3                23.64                         0.987023
# 4                23.64                         0.987023
#
#    Barometric Pressure_Intercept
# 0                       0.291402
# 1                       0.291402
# 2                       0.291402
# 3                       0.291402
# 4                       0.291402
#
# Calibrated values for 'Barometric Pressure' in 'Indoor15.csv':
#    Barometric Pressure
# 0            23.624634
# 1            23.624634
# 2            23.624634
# 3            23.624634
# 4            23.624634
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                   0.0                          0.779321  \
# 1                   0.0                          0.779321
# 2                   0.0                          0.779321
# 3                   0.0                          0.779321
# 4                   0.0                          0.779321
#
#    VOC tVOC measurement_Intercept
# 0                        0.017228
# 1                        0.017228
# 2                        0.017228
# 3                        0.017228
# 4                        0.017228
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor15.csv':
#    VOC tVOC measurement
# 0              0.017228
# 1              0.017228
# 2              0.017228
# 3              0.017228
# 4              0.017228
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         73.2                 1.013987              -0.913603
# 1         73.2                 1.013987              -0.913603
# 2         73.2                 1.013987              -0.913603
# 3         73.0                 1.013987              -0.913603
# 4         73.0                 1.013987              -0.913603
#
# Calibrated values for 'Temperature' in 'Indoor15.csv':
#    Temperature
# 0    73.310258
# 1    73.310258
# 2    73.310258
# 3    73.107460
# 4    73.107460
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               52.0                       0.993211  \
# 1               52.0                       0.993211
# 2               52.0                       0.993211
# 3               52.0                       0.993211
# 4               52.0                       0.993211
#
#    Relative Humidity_Intercept
# 0                    -0.278815
# 1                    -0.278815
# 2                    -0.278815
# 3                    -0.278815
# 4                    -0.278815
#
# Calibrated values for 'Relative Humidity' in 'Indoor15.csv':
#    Relative Humidity
# 0          51.368182
# 1          51.368182
# 2          51.368182
# 3          51.368182
# 4          51.368182
#
# Processing file: Indoor03.csv with Sensor ID: Indoor03
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    23.0            0.981287          0.023288
# 1    22.0            0.981287          0.023288
# 2    22.0            0.981287          0.023288
# 3    21.0            0.981287          0.023288
# 4    20.0            0.981287          0.023288
#
# Calibrated values for 'PM 2.5' in 'Indoor03.csv':
#       PM 2.5
# 0  22.592899
# 1  21.611611
# 2  21.611611
# 3  20.630324
# 4  19.649036
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  457.0         0.919307      35.743386
# 1  451.0         0.919307      35.743386
# 2  452.0         0.919307      35.743386
# 3  456.0         0.919307      35.743386
# 4  448.0         0.919307      35.743386
#
# Calibrated values for 'CO2' in 'Indoor03.csv':
#           CO2
# 0  455.866491
# 1  450.350652
# 2  451.269958
# 3  454.947184
# 4  447.592732
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.53                         0.983661  \
# 1                23.53                         0.983661
# 2                23.53                         0.983661
# 3                23.53                         0.983661
# 4                23.53                         0.983661
#
#    Barometric Pressure_Intercept
# 0                       0.411439
# 1                       0.411439
# 2                       0.411439
# 3                       0.411439
# 4                       0.411439
#
# Calibrated values for 'Barometric Pressure' in 'Indoor03.csv':
#    Barometric Pressure
# 0            23.556986
# 1            23.556986
# 2            23.556986
# 3            23.556986
# 4            23.556986
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.020                          0.953878  \
# 1                 0.025                          0.953878
# 2                 0.040                          0.953878
# 3                 0.040                          0.953878
# 4                 0.044                          0.953878
#
#    VOC tVOC measurement_Intercept
# 0                        0.051535
# 1                        0.051535
# 2                        0.051535
# 3                        0.051535
# 4                        0.051535
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor03.csv':
#    VOC tVOC measurement
# 0              0.070613
# 1              0.075382
# 2              0.089691
# 3              0.089691
# 4              0.093506
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         73.2                  1.02408              -1.607788
# 1         73.2                  1.02408              -1.607788
# 2         73.0                  1.02408              -1.607788
# 3         73.0                  1.02408              -1.607788
# 4         73.0                  1.02408              -1.607788
#
# Calibrated values for 'Temperature' in 'Indoor03.csv':
#    Temperature
# 0    73.354883
# 1    73.354883
# 2    73.150067
# 3    73.150067
# 4    73.150067
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               56.0                       1.017823  \
# 1               56.0                       1.017823
# 2               55.0                       1.017823
# 3               55.0                       1.017823
# 4               55.0                       1.017823
#
#    Relative Humidity_Intercept
# 0                    -2.063793
# 1                    -2.063793
# 2                    -2.063793
# 3                    -2.063793
# 4                    -2.063793
#
# Calibrated values for 'Relative Humidity' in 'Indoor03.csv':
#    Relative Humidity
# 0          54.934318
# 1          54.934318
# 2          53.916495
# 3          53.916495
# 4          53.916495
#
# Processing file: Indoor02.csv with Sensor ID: Indoor02
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0     7.0            2.865331          1.350421
# 1     6.0            2.865331          1.350421
# 2     6.0            2.865331          1.350421
# 3     6.0            2.865331          1.350421
# 4     6.0            2.865331          1.350421
#
# Calibrated values for 'PM 2.5' in 'Indoor02.csv':
#       PM 2.5
# 0  21.407739
# 1  18.542408
# 2  18.542408
# 3  18.542408
# 4  18.542408
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  489.0          1.00709      -3.797409
# 1  487.0          1.00709      -3.797409
# 2  490.0          1.00709      -3.797409
# 3  493.0          1.00709      -3.797409
# 4  494.0          1.00709      -3.797409
#
# Calibrated values for 'CO2' in 'Indoor02.csv':
#           CO2
# 0  488.669803
# 1  486.655622
# 2  489.676894
# 3  492.698165
# 4  493.705255
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.57                         0.990223  \
# 1                23.57                         0.990223
# 2                23.57                         0.990223
# 3                23.57                         0.990223
# 4                23.57                         0.990223
#
#    Barometric Pressure_Intercept
# 0                       0.249064
# 1                       0.249064
# 2                       0.249064
# 3                       0.249064
# 4                       0.249064
#
# Calibrated values for 'Barometric Pressure' in 'Indoor02.csv':
#    Barometric Pressure
# 0             23.58862
# 1             23.58862
# 2             23.58862
# 3             23.58862
# 4             23.58862
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.017                          0.962169  \
# 1                 0.016                          0.962169
# 2                 0.017                          0.962169
# 3                 0.016                          0.962169
# 4                 0.015                          0.962169
#
#    VOC tVOC measurement_Intercept
# 0                        0.005709
# 1                        0.005709
# 2                        0.005709
# 3                        0.005709
# 4                        0.005709
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor02.csv':
#    VOC tVOC measurement
# 0              0.022066
# 1              0.021103
# 2              0.022066
# 3              0.021103
# 4              0.020141
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         71.8                  0.94523               3.991724
# 1         71.8                  0.94523               3.991724
# 2         71.6                  0.94523               3.991724
# 3         71.6                  0.94523               3.991724
# 4         71.4                  0.94523               3.991724
#
# Calibrated values for 'Temperature' in 'Indoor02.csv':
#    Temperature
# 0    71.859232
# 1    71.859232
# 2    71.670186
# 3    71.670186
# 4    71.481140
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               56.0                       0.966599  \
# 1               56.0                       0.966599
# 2               56.0                       0.966599
# 3               56.0                       0.966599
# 4               56.0                       0.966599
#
#    Relative Humidity_Intercept
# 0                     2.307922
# 1                     2.307922
# 2                     2.307922
# 3                     2.307922
# 4                     2.307922
#
# Calibrated values for 'Relative Humidity' in 'Indoor02.csv':
#    Relative Humidity
# 0          56.437484
# 1          56.437484
# 2          56.437484
# 3          56.437484
# 4          56.437484
#
# Processing file: Indoor06.csv with Sensor ID: Indoor06
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0     6.0            2.668769          0.974337
# 1     5.0            2.668769          0.974337
# 2     4.0            2.668769          0.974337
# 3     4.0            2.668769          0.974337
# 4     4.0            2.668769          0.974337
#
# Calibrated values for 'PM 2.5' in 'Indoor06.csv':
#       PM 2.5
# 0  16.986952
# 1  14.318183
# 2  11.649414
# 3  11.649414
# 4  11.649414
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  426.0         0.954395      27.491217
# 1  419.0         0.954395      27.491217
# 2  420.0         0.954395      27.491217
# 3  421.0         0.954395      27.491217
# 4  432.0         0.954395      27.491217
#
# Calibrated values for 'CO2' in 'Indoor06.csv':
#           CO2
# 0  434.063352
# 1  427.382589
# 2  428.336984
# 3  429.291378
# 4  439.789720
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.55                          0.99487  \
# 1                23.54                          0.99487
# 2                23.54                          0.99487
# 3                23.55                          0.99487
# 4                23.55                          0.99487
#
#    Barometric Pressure_Intercept
# 0                       0.091486
# 1                       0.091486
# 2                       0.091486
# 3                       0.091486
# 4                       0.091486
#
# Calibrated values for 'Barometric Pressure' in 'Indoor06.csv':
#    Barometric Pressure
# 0            23.520673
# 1            23.510724
# 2            23.510724
# 3            23.520673
# 4            23.520673
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.928                          0.925275  \
# 1                 0.909                          0.925275
# 2                 0.893                          0.925275
# 3                 0.880                          0.925275
# 4                 0.917                          0.925275
#
#    VOC tVOC measurement_Intercept
# 0                        0.034388
# 1                        0.034388
# 2                        0.034388
# 3                        0.034388
# 4                        0.034388
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor06.csv':
#    VOC tVOC measurement
# 0              0.893043
# 1              0.875463
# 2              0.860659
# 3              0.848630
# 4              0.882865
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         75.4                  0.96483               2.646125
# 1         75.4                  0.96483               2.646125
# 2         75.2                  0.96483               2.646125
# 3         75.0                  0.96483               2.646125
# 4         75.0                  0.96483               2.646125
#
# Calibrated values for 'Temperature' in 'Indoor06.csv':
#    Temperature
# 0    75.394324
# 1    75.394324
# 2    75.201358
# 3    75.008392
# 4    75.008392
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               38.0                         0.9712  \
# 1               38.0                         0.9712
# 2               39.0                         0.9712
# 3               39.0                         0.9712
# 4               40.0                         0.9712
#
#    Relative Humidity_Intercept
# 0                     1.548206
# 1                     1.548206
# 2                     1.548206
# 3                     1.548206
# 4                     1.548206
#
# Calibrated values for 'Relative Humidity' in 'Indoor06.csv':
#    Relative Humidity
# 0          38.453795
# 1          38.453795
# 2          39.424994
# 3          39.424994
# 4          40.396194
#
# Processing file: Indoor12.csv with Sensor ID: Indoor12
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    17.0            0.957579          0.305028
# 1    14.0            0.957579          0.305028
# 2    12.0            0.957579          0.305028
# 3    10.0            0.957579          0.305028
# 4    10.0            0.957579          0.305028
#
# Calibrated values for 'PM 2.5' in 'Indoor12.csv':
#       PM 2.5
# 0  16.583868
# 1  13.711132
# 2  11.795974
# 3   9.880816
# 4   9.880816
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  642.0         0.873902      54.533313
# 1  653.0         0.873902      54.533313
# 2  648.0         0.873902      54.533313
# 3  612.0         0.873902      54.533313
# 4  592.0         0.873902      54.533313
#
# Calibrated values for 'CO2' in 'Indoor12.csv':
#           CO2
# 0  615.578277
# 1  625.191197
# 2  620.821688
# 3  589.361222
# 4  571.883186
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.48                         0.995004  \
# 1                23.48                         0.995004
# 2                23.48                         0.995004
# 3                23.48                         0.995004
# 4                23.49                         0.995004
#
#    Barometric Pressure_Intercept
# 0                       0.118713
# 1                       0.118713
# 2                       0.118713
# 3                       0.118713
# 4                       0.118713
#
# Calibrated values for 'Barometric Pressure' in 'Indoor12.csv':
#    Barometric Pressure
# 0            23.481405
# 1            23.481405
# 2            23.481405
# 3            23.481405
# 4            23.491355
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.959                           0.94197  \
# 1                 0.953                           0.94197
# 2                 0.919                           0.94197
# 3                 0.863                           0.94197
# 4                 0.831                           0.94197
#
#    VOC tVOC measurement_Intercept
# 0                        0.038899
# 1                        0.038899
# 2                        0.038899
# 3                        0.038899
# 4                        0.038899
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor12.csv':
#    VOC tVOC measurement
# 0              0.942248
# 1              0.936596
# 2              0.904569
# 3              0.851819
# 4              0.821676
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         60.8                 0.913395                6.16842
# 1         60.6                 0.913395                6.16842
# 2         60.3                 0.913395                6.16842
# 3         59.9                 0.913395                6.16842
# 4         59.5                 0.913395                6.16842
#
# Calibrated values for 'Temperature' in 'Indoor12.csv':
#    Temperature
# 0    61.702846
# 1    61.520167
# 2    61.246148
# 3    60.880790
# 4    60.515432
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               80.0                       1.036515  \
# 1               80.0                       1.036515
# 2               80.0                       1.036515
# 3               81.0                       1.036515
# 4               82.0                       1.036515
#
#    Relative Humidity_Intercept
# 0                    -5.527539
# 1                    -5.527539
# 2                    -5.527539
# 3                    -5.527539
# 4                    -5.527539
#
# Calibrated values for 'Relative Humidity' in 'Indoor12.csv':
#    Relative Humidity
# 0          77.393682
# 1          77.393682
# 2          77.393682
# 3          78.430197
# 4          79.466712
#
# Processing file: Indoor13.csv with Sensor ID: Indoor13
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    25.0            0.907568          0.344791
# 1    22.0            0.907568          0.344791
# 2    20.0            0.907568          0.344791
# 3    19.0            0.907568          0.344791
# 4    17.0            0.907568          0.344791
#
# Calibrated values for 'PM 2.5' in 'Indoor13.csv':
#       PM 2.5
# 0  23.034000
# 1  20.311295
# 2  18.496159
# 3  17.588590
# 4  15.773454
#
# Before calibration for 'CO2':
#       CO2  CO2_Coefficient  CO2_Intercept
# 0  1923.0         0.979905       7.638423
# 1  1808.0         0.979905       7.638423
# 2  1832.0         0.979905       7.638423
# 3  1849.0         0.979905       7.638423
# 4  1889.0         0.979905       7.638423
#
# Calibrated values for 'CO2' in 'Indoor13.csv':
#            CO2
# 0  1891.996061
# 1  1779.306966
# 2  1802.824690
# 3  1819.483078
# 4  1858.679285
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.40                         0.982774  \
# 1                23.40                         0.982774
# 2                23.40                         0.982774
# 3                23.41                         0.982774
# 4                23.41                         0.982774
#
#    Barometric Pressure_Intercept
# 0                       0.392693
# 1                       0.392693
# 2                       0.392693
# 3                       0.392693
# 4                       0.392693
#
# Calibrated values for 'Barometric Pressure' in 'Indoor13.csv':
#    Barometric Pressure
# 0            23.389610
# 1            23.389610
# 2            23.389610
# 3            23.399438
# 4            23.399438
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.889                          0.952425  \
# 1                 0.935                          0.952425
# 2                 0.911                          0.952425
# 3                 0.882                          0.952425
# 4                 0.884                          0.952425
#
#    VOC tVOC measurement_Intercept
# 0                        0.014127
# 1                        0.014127
# 2                        0.014127
# 3                        0.014127
# 4                        0.014127
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor13.csv':
#    VOC tVOC measurement
# 0              0.860833
# 1              0.904644
# 2              0.881786
# 3              0.854166
# 4              0.856070
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         72.5                 1.039909              -2.825404
# 1         72.3                 1.039909              -2.825404
# 2         72.1                 1.039909              -2.825404
# 3         71.8                 1.039909              -2.825404
# 4         71.6                 1.039909              -2.825404
#
# Calibrated values for 'Temperature' in 'Indoor13.csv':
#    Temperature
# 0    72.568007
# 1    72.360025
# 2    72.152044
# 3    71.840071
# 4    71.632089
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               65.0                       1.009238  \
# 1               65.0                       1.009238
# 2               65.0                       1.009238
# 3               65.0                       1.009238
# 4               65.0                       1.009238
#
#    Relative Humidity_Intercept
# 0                    -0.208683
# 1                    -0.208683
# 2                    -0.208683
# 3                    -0.208683
# 4                    -0.208683
#
# Calibrated values for 'Relative Humidity' in 'Indoor13.csv':
#    Relative Humidity
# 0          65.391804
# 1          65.391804
# 2          65.391804
# 3          65.391804
# 4          65.391804
#
# Processing file: Indoor07.csv with Sensor ID: Indoor07
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    12.0            2.170936          0.485796
# 1    11.0            2.170936          0.485796
# 2    10.0            2.170936          0.485796
# 3     9.0            2.170936          0.485796
# 4     8.0            2.170936          0.485796
#
# Calibrated values for 'PM 2.5' in 'Indoor07.csv':
#       PM 2.5
# 0  26.537029
# 1  24.366093
# 2  22.195157
# 3  20.024221
# 4  17.853285
#
# Before calibration for 'CO2':
#       CO2  CO2_Coefficient  CO2_Intercept
# 0  1015.0         0.915331      38.397817
# 1  1018.0         0.915331      38.397817
# 2   997.0         0.915331      38.397817
# 3   967.0         0.915331      38.397817
# 4   970.0         0.915331      38.397817
#
# Calibrated values for 'CO2' in 'Indoor07.csv':
#           CO2
# 0  967.459095
# 1  970.205089
# 2  950.983131
# 3  923.523192
# 4  926.269186
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.46                         0.988985  \
# 1                23.46                         0.988985
# 2                23.46                         0.988985
# 3                23.46                         0.988985
# 4                23.46                         0.988985
#
#    Barometric Pressure_Intercept
# 0                        0.26336
# 1                        0.26336
# 2                        0.26336
# 3                        0.26336
# 4                        0.26336
#
# Calibrated values for 'Barometric Pressure' in 'Indoor07.csv':
#    Barometric Pressure
# 0            23.464943
# 1            23.464943
# 2            23.464943
# 3            23.464943
# 4            23.464943
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.107                          0.714957  \
# 1                 0.094                          0.714957
# 2                 0.029                          0.714957
# 3                 0.003                          0.714957
# 4                 0.000                          0.714957
#
#    VOC tVOC measurement_Intercept
# 0                        0.051517
# 1                        0.051517
# 2                        0.051517
# 3                        0.051517
# 4                        0.051517
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor07.csv':
#    VOC tVOC measurement
# 0              0.128017
# 1              0.118722
# 2              0.072250
# 3              0.053661
# 4              0.051517
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         68.5                  1.01923              -1.424217
# 1         68.4                  1.01923              -1.424217
# 2         68.0                  1.01923              -1.424217
# 3         68.0                  1.01923              -1.424217
# 4         67.8                  1.01923              -1.424217
#
# Calibrated values for 'Temperature' in 'Indoor07.csv':
#    Temperature
# 0    68.393007
# 1    68.291084
# 2    67.883392
# 3    67.883392
# 4    67.679546
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               61.0                        0.99944  \
# 1               62.0                        0.99944
# 2               62.0                        0.99944
# 3               62.0                        0.99944
# 4               62.0                        0.99944
#
#    Relative Humidity_Intercept
# 0                    -1.068002
# 1                    -1.068002
# 2                    -1.068002
# 3                    -1.068002
# 4                    -1.068002
#
# Calibrated values for 'Relative Humidity' in 'Indoor07.csv':
#    Relative Humidity
# 0          59.897845
# 1          60.897285
# 2          60.897285
# 3          60.897285
# 4          60.897285
#
# Processing file: Indoor11.csv with Sensor ID: Indoor11
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    24.0             2.02326          0.499401
# 1    21.0             2.02326          0.499401
# 2    19.0             2.02326          0.499401
# 3    17.0             2.02326          0.499401
# 4    16.0             2.02326          0.499401
#
# Calibrated values for 'PM 2.5' in 'Indoor11.csv':
#       PM 2.5
# 0  49.057634
# 1  42.987855
# 2  38.941336
# 3  34.894816
# 4  32.871556
#
# Before calibration for 'CO2':
#       CO2  CO2_Coefficient  CO2_Intercept
# 0  1408.0          0.92024      32.693212
# 1  1359.0          0.92024      32.693212
# 2  1317.0          0.92024      32.693212
# 3  1283.0          0.92024      32.693212
# 4  1255.0          0.92024      32.693212
#
# Calibrated values for 'CO2' in 'Indoor11.csv':
#            CO2
# 0  1328.391360
# 1  1283.299592
# 2  1244.649505
# 3  1213.361340
# 4  1187.594615
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.57                         0.978113  \
# 1                23.57                         0.978113
# 2                23.57                         0.978113
# 3                23.57                         0.978113
# 4                23.58                         0.978113
#
#    Barometric Pressure_Intercept
# 0                       0.510819
# 1                       0.510819
# 2                       0.510819
# 3                       0.510819
# 4                       0.510819
#
# Calibrated values for 'Barometric Pressure' in 'Indoor11.csv':
#    Barometric Pressure
# 0            23.564941
# 1            23.564941
# 2            23.564941
# 3            23.564941
# 4            23.574722
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 1.004                          0.937455  \
# 1                 0.980                          0.937455
# 2                 0.966                          0.937455
# 3                 0.954                          0.937455
# 4                 0.945                          0.937455
#
#    VOC tVOC measurement_Intercept
# 0                        0.033349
# 1                        0.033349
# 2                        0.033349
# 3                        0.033349
# 4                        0.033349
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor11.csv':
#    VOC tVOC measurement
# 0              0.974554
# 1              0.952055
# 2              0.938931
# 3              0.927681
# 4              0.919244
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         73.4                 1.043613              -3.376673
# 1         73.2                 1.043613              -3.376673
# 2         73.2                 1.043613              -3.376673
# 3         73.0                 1.043613              -3.376673
# 4         72.9                 1.043613              -3.376673
#
# Calibrated values for 'Temperature' in 'Indoor11.csv':
#    Temperature
# 0    73.224534
# 1    73.015812
# 2    73.015812
# 3    72.807089
# 4    72.702728
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               61.0                       1.014429  \
# 1               61.0                       1.014429
# 2               61.0                       1.014429
# 3               60.0                       1.014429
# 4               61.0                       1.014429
#
#    Relative Humidity_Intercept
# 0                     -1.63044
# 1                     -1.63044
# 2                     -1.63044
# 3                     -1.63044
# 4                     -1.63044
#
# Calibrated values for 'Relative Humidity' in 'Indoor11.csv':
#    Relative Humidity
# 0          60.249739
# 1          60.249739
# 2          60.249739
# 3          59.235310
# 4          60.249739
#
# Processing file: Indoor05.csv with Sensor ID: Indoor05
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    62.0            1.001332         -0.098173
# 1    88.0            1.001332         -0.098173
# 2    94.0            1.001332         -0.098173
# 3    82.0            1.001332         -0.098173
# 4    65.0            1.001332         -0.098173
#
# Calibrated values for 'PM 2.5' in 'Indoor05.csv':
#       PM 2.5
# 0  61.984399
# 1  88.019026
# 2  94.027017
# 3  82.011035
# 4  64.988395
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  476.0          1.01381      -7.277955
# 1  477.0          1.01381      -7.277955
# 2  473.0          1.01381      -7.277955
# 3  468.0          1.01381      -7.277955
# 4  450.0          1.01381      -7.277955
#
# Calibrated values for 'CO2' in 'Indoor05.csv':
#           CO2
# 0  475.295455
# 1  476.309264
# 2  472.254026
# 3  467.184977
# 4  448.936403
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.58                         0.992086  \
# 1                23.58                         0.992086
# 2                23.59                         0.992086
# 3                23.58                         0.992086
# 4                23.58                         0.992086
#
#    Barometric Pressure_Intercept
# 0                        0.19521
# 1                        0.19521
# 2                        0.19521
# 3                        0.19521
# 4                        0.19521
#
# Calibrated values for 'Barometric Pressure' in 'Indoor05.csv':
#    Barometric Pressure
# 0            23.588595
# 1            23.588595
# 2            23.598516
# 3            23.588595
# 4            23.588595
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.904                          1.004363  \
# 1                 0.957                          1.004363
# 2                 0.971                          1.004363
# 3                 0.931                          1.004363
# 4                 0.879                          1.004363
#
#    VOC tVOC measurement_Intercept
# 0                       -0.006231
# 1                       -0.006231
# 2                       -0.006231
# 3                       -0.006231
# 4                       -0.006231
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor05.csv':
#    VOC tVOC measurement
# 0              0.901713
# 1              0.954944
# 2              0.969005
# 3              0.928831
# 4              0.876604
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         73.8                  0.91173                6.14723
# 1         73.6                  0.91173                6.14723
# 2         73.4                  0.91173                6.14723
# 3         73.4                  0.91173                6.14723
# 4         73.4                  0.91173                6.14723
#
# Calibrated values for 'Temperature' in 'Indoor05.csv':
#    Temperature
# 0    73.432937
# 1    73.250591
# 2    73.068245
# 3    73.068245
# 4    73.068245
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               50.0                       0.980267  \
# 1               50.0                       0.980267
# 2               50.0                       0.980267
# 3               50.0                       0.980267
# 4               49.0                       0.980267
#
#    Relative Humidity_Intercept
# 0                     2.011482
# 1                     2.011482
# 2                     2.011482
# 3                     2.011482
# 4                     2.011482
#
# Calibrated values for 'Relative Humidity' in 'Indoor05.csv':
#    Relative Humidity
# 0          51.024841
# 1          51.024841
# 2          51.024841
# 3          51.024841
# 4          50.044574
#
# Processing file: Indoor04.csv with Sensor ID: Indoor04
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0     7.0            2.136437          0.501952
# 1     6.0            2.136437          0.501952
# 2     6.0            2.136437          0.501952
# 3     6.0            2.136437          0.501952
# 4     5.0            2.136437          0.501952
#
# Calibrated values for 'PM 2.5' in 'Indoor04.csv':
#       PM 2.5
# 0  15.457009
# 1  13.320572
# 2  13.320572
# 3  13.320572
# 4  11.184136
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  462.0         0.911782      39.828079
# 1  461.0         0.911782      39.828079
# 2  459.0         0.911782      39.828079
# 3  450.0         0.911782      39.828079
# 4  458.0         0.911782      39.828079
#
# Calibrated values for 'CO2' in 'Indoor04.csv':
#           CO2
# 0  461.071546
# 1  460.159764
# 2  458.336199
# 3  450.130157
# 4  457.424417
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.59                          0.95226  \
# 1                23.59                          0.95226
# 2                23.59                          0.95226
# 3                23.59                          0.95226
# 4                23.59                          0.95226
#
#    Barometric Pressure_Intercept
# 0                       1.113093
# 1                       1.113093
# 2                       1.113093
# 3                       1.113093
# 4                       1.113093
#
# Calibrated values for 'Barometric Pressure' in 'Indoor04.csv':
#    Barometric Pressure
# 0            23.576912
# 1            23.576912
# 2            23.576912
# 3            23.576912
# 4            23.576912
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.507                          0.794343  \
# 1                 0.490                          0.794343
# 2                 0.485                          0.794343
# 3                 0.487                          0.794343
# 4                 0.462                          0.794343
#
#    VOC tVOC measurement_Intercept
# 0                        0.027624
# 1                        0.027624
# 2                        0.027624
# 3                        0.027624
# 4                        0.027624
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor04.csv':
#    VOC tVOC measurement
# 0              0.430356
# 1              0.416852
# 2              0.412880
# 3              0.414469
# 4              0.394610
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         72.9                  0.92834               5.307592
# 1         72.9                  0.92834               5.307592
# 2         72.7                  0.92834               5.307592
# 3         72.5                  0.92834               5.307592
# 4         72.5                  0.92834               5.307592
#
# Calibrated values for 'Temperature' in 'Indoor04.csv':
#    Temperature
# 0    72.983570
# 1    72.983570
# 2    72.797902
# 3    72.612234
# 4    72.612234
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               56.0                       0.958677  \
# 1               56.0                       0.958677
# 2               56.0                       0.958677
# 3               56.0                       0.958677
# 4               55.0                       0.958677
#
#    Relative Humidity_Intercept
# 0                     2.464426
# 1                     2.464426
# 2                     2.464426
# 3                     2.464426
# 4                     2.464426
#
# Calibrated values for 'Relative Humidity' in 'Indoor04.csv':
#    Relative Humidity
# 0          56.150313
# 1          56.150313
# 2          56.150313
# 3          56.150313
# 4          55.191636
#
# Processing file: Indoor10.csv with Sensor ID: Indoor10
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    56.0            0.855936         -0.491604
# 1    53.0            0.855936         -0.491604
# 2    51.0            0.855936         -0.491604
# 3    51.0            0.855936         -0.491604
# 4    48.0            0.855936         -0.491604
#
# Calibrated values for 'PM 2.5' in 'Indoor10.csv':
#       PM 2.5
# 0  47.440810
# 1  44.873002
# 2  43.161130
# 3  43.161130
# 4  40.593322
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  422.0         0.902484      41.375185
# 1  429.0         0.902484      41.375185
# 2  451.0         0.902484      41.375185
# 3  453.0         0.902484      41.375185
# 4  463.0         0.902484      41.375185
#
# Calibrated values for 'CO2' in 'Indoor10.csv':
#           CO2
# 0  422.223610
# 1  428.541001
# 2  448.395658
# 3  450.200627
# 4  459.225471
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                24.05                         0.989295  \
# 1                24.06                         0.989295
# 2                24.06                         0.989295
# 3                24.06                         0.989295
# 4                24.06                         0.989295
#
#    Barometric Pressure_Intercept
# 0                       0.216606
# 1                       0.216606
# 2                       0.216606
# 3                       0.216606
# 4                       0.216606
#
# Calibrated values for 'Barometric Pressure' in 'Indoor10.csv':
#    Barometric Pressure
# 0            24.009143
# 1            24.019036
# 2            24.019036
# 3            24.019036
# 4            24.019036
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                   0.0                           0.75426  \
# 1                   0.0                           0.75426
# 2                   0.0                           0.75426
# 3                   0.0                           0.75426
# 4                   0.0                           0.75426
#
#    VOC tVOC measurement_Intercept
# 0                       -0.020859
# 1                       -0.020859
# 2                       -0.020859
# 3                       -0.020859
# 4                       -0.020859
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor10.csv':
#    VOC tVOC measurement
# 0             -0.020859
# 1             -0.020859
# 2             -0.020859
# 3             -0.020859
# 4             -0.020859
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         71.6                 0.997952               0.140373
# 1         71.6                 0.997952               0.140373
# 2         71.6                 0.997952               0.140373
# 3         71.4                 0.997952               0.140373
# 4         71.4                 0.997952               0.140373
#
# Calibrated values for 'Temperature' in 'Indoor10.csv':
#    Temperature
# 0    71.593719
# 1    71.593719
# 2    71.593719
# 3    71.394128
# 4    71.394128
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               70.0                       0.984946  \
# 1               69.0                       0.984946
# 2               69.0                       0.984946
# 3               68.0                       0.984946
# 4               68.0                       0.984946
#
#    Relative Humidity_Intercept
# 0                     1.343864
# 1                     1.343864
# 2                     1.343864
# 3                     1.343864
# 4                     1.343864
#
# Calibrated values for 'Relative Humidity' in 'Indoor10.csv':
#    Relative Humidity
# 0          70.290090
# 1          69.305144
# 2          69.305144
# 3          68.320198
# 4          68.320198
#
# Processing file: Indoor09.csv with Sensor ID: Indoor09
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    57.0            0.537437         -0.384572
# 1    52.0            0.537437         -0.384572
# 2    49.0            0.537437         -0.384572
# 3    46.0            0.537437         -0.384572
# 4    46.0            0.537437         -0.384572
#
# Calibrated values for 'PM 2.5' in 'Indoor09.csv':
#       PM 2.5
# 0  30.249354
# 1  27.562168
# 2  25.949856
# 3  24.337544
# 4  24.337544
#
# Before calibration for 'CO2':
#       CO2  CO2_Coefficient  CO2_Intercept
# 0  1332.0         0.807396      73.656881
# 1  1304.0         0.807396      73.656881
# 2  1340.0         0.807396      73.656881
# 3  1388.0         0.807396      73.656881
# 4  1317.0         0.807396      73.656881
#
# Calibrated values for 'CO2' in 'Indoor09.csv':
#            CO2
# 0  1149.108279
# 1  1126.501193
# 2  1155.567447
# 3  1194.322452
# 4  1136.997340
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.52                         0.983116  \
# 1                23.52                         0.983116
# 2                23.53                         0.983116
# 3                23.53                         0.983116
# 4                23.53                         0.983116
#
#    Barometric Pressure_Intercept
# 0                       0.403921
# 1                       0.403921
# 2                       0.403921
# 3                       0.403921
# 4                       0.403921
#
# Calibrated values for 'Barometric Pressure' in 'Indoor09.csv':
#    Barometric Pressure
# 0            23.526815
# 1            23.526815
# 2            23.536646
# 3            23.536646
# 4            23.536646
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.000                          0.994709  \
# 1                 0.000                          0.994709
# 2                 0.015                          0.994709
# 3                 0.000                          0.994709
# 4                 0.033                          0.994709
#
#    VOC tVOC measurement_Intercept
# 0                        0.005496
# 1                        0.005496
# 2                        0.005496
# 3                        0.005496
# 4                        0.005496
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor09.csv':
#    VOC tVOC measurement
# 0              0.005496
# 1              0.005496
# 2              0.020417
# 3              0.005496
# 4              0.038322
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         72.5                  1.00348              -0.398989
# 1         72.3                  1.00348              -0.398989
# 2         72.1                  1.00348              -0.398989
# 3         71.8                  1.00348              -0.398989
# 4         71.6                  1.00348              -0.398989
#
# Calibrated values for 'Temperature' in 'Indoor09.csv':
#    Temperature
# 0    72.353317
# 1    72.152621
# 2    71.951925
# 3    71.650881
# 4    71.450185
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               63.0                       1.026145  \
# 1               63.0                       1.026145
# 2               63.0                       1.026145
# 3               63.0                       1.026145
# 4               63.0                       1.026145
#
#    Relative Humidity_Intercept
# 0                    -0.327177
# 1                    -0.327177
# 2                    -0.327177
# 3                    -0.327177
# 4                    -0.327177
#
# Calibrated values for 'Relative Humidity' in 'Indoor09.csv':
#    Relative Humidity
# 0          64.319975
# 1          64.319975
# 2          64.319975
# 3          64.319975
# 4          64.319975
#
# Processing file: Indoor08.csv with Sensor ID: Indoor08
#
# Before calibration for 'PM 2.5':
#    PM 2.5  PM 2.5_Coefficient  PM 2.5_Intercept
# 0    92.0            0.544995          1.270026
# 1   102.0            0.544995          1.270026
# 2    92.0            0.544995          1.270026
# 3    80.0            0.544995          1.270026
# 4    75.0            0.544995          1.270026
#
# Calibrated values for 'PM 2.5' in 'Indoor08.csv':
#       PM 2.5
# 0  51.409538
# 1  56.859485
# 2  51.409538
# 3  44.869602
# 4  42.144628
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  832.0         1.027887      -8.171484
# 1  805.0         1.027887      -8.171484
# 2  786.0         1.027887      -8.171484
# 3  757.0         1.027887      -8.171484
# 4  744.0         1.027887      -8.171484
#
# Calibrated values for 'CO2' in 'Indoor08.csv':
#           CO2
# 0  847.030901
# 1  819.277939
# 2  799.748077
# 3  769.939340
# 4  756.576802
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.60                         0.987958  \
# 1                23.60                         0.987958
# 2                23.61                         0.987958
# 3                23.61                         0.987958
# 4                23.61                         0.987958
#
#    Barometric Pressure_Intercept
# 0                       0.311098
# 1                       0.311098
# 2                       0.311098
# 3                       0.311098
# 4                       0.311098
#
# Calibrated values for 'Barometric Pressure' in 'Indoor08.csv':
#    Barometric Pressure
# 0            23.626897
# 1            23.626897
# 2            23.636776
# 3            23.636776
# 4            23.636776
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.012                          0.862304  \
# 1                 0.003                          0.862304
# 2                 0.013                          0.862304
# 3                 0.003                          0.862304
# 4                 0.007                          0.862304
#
#    VOC tVOC measurement_Intercept
# 0                       -0.013925
# 1                       -0.013925
# 2                       -0.013925
# 3                       -0.013925
# 4                       -0.013925
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor08.csv':
#    VOC tVOC measurement
# 0             -0.003577
# 1             -0.011338
# 2             -0.002715
# 3             -0.011338
# 4             -0.007889
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         71.6                 0.932966               4.721146
# 1         71.4                 0.932966               4.721146
# 2         71.1                 0.932966               4.721146
# 3         70.9                 0.932966               4.721146
# 4         70.5                 0.932966               4.721146
#
# Calibrated values for 'Temperature' in 'Indoor08.csv':
#    Temperature
# 0    71.521504
# 1    71.334910
# 2    71.055021
# 3    70.868427
# 4    70.495241
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0               66.0                       0.987473  \
# 1               66.0                       0.987473
# 2               66.0                       0.987473
# 3               66.0                       0.987473
# 4               67.0                       0.987473
#
#    Relative Humidity_Intercept
# 0                     1.436715
# 1                     1.436715
# 2                     1.436715
# 3                     1.436715
# 4                     1.436715
#
# Calibrated values for 'Relative Humidity' in 'Indoor08.csv':
#    Relative Humidity
# 0          66.609954
# 1          66.609954
# 2          66.609954
# 3          66.609954
# 4          67.597427
# All harmonized datasets have been saved.

# %% [markdown]
# ## Outdoor Sensors

# %%
# Directories
raw_dir = 'data/raw/outdoor'  # Directory containing the raw outdoor data files
cleaned_dir = 'data/outdoor_cleaned'  # Directory to save the cleaned outdoor data

# Ensure the cleaned directory exists
os.makedirs(cleaned_dir, exist_ok=True)

# Sensor names for mapping
sensor_names = ['outdoor01', 'outdoor02', 'outdoor03']

# Define the cleaning function for outdoor sensors
def clean_sensor_dataframes_outdoor(sensor_dataframes):
    numeric_columns = ['PM 1.0', 'PM 2.5', 'PM 4.0', 'PM 10',
                       'NC 0.5', 'NC 1.0', 'NC 2.5', 'NC 10',
                       'Temperature', 'Relative Humidity']
    cleaned_dataframes = []
    
    # Determine which columns are present and which are missing
    columns_not_present = list(set(numeric_columns) - set(sensor_dataframes[0].columns.to_list()))
    columns_present = [x for x in numeric_columns if x not in columns_not_present]

    print(f'Columns not present in the Dataframe: {columns_not_present}')

    # Loop through each sensor DataFrame for cleaning
    for sensor_df in sensor_dataframes:
        # Remove header
        sensor_df = sensor_df.iloc[1:]
        # Sort by 'Timestamp'
        sensor_df = sensor_df.sort_values(by=['Timestamp']).reset_index(drop=True)
        # Change 'Timestamp' to date format
        sensor_df['Timestamp'] = pd.to_datetime(sensor_df['Timestamp'], errors='coerce')
        # Convert specified columns to numeric
        sensor_df[columns_present] = sensor_df[columns_present].apply(pd.to_numeric, errors='coerce')
        # Append the cleaned DataFrame to the list
        cleaned_dataframes.append(sensor_df)
    
    return cleaned_dataframes

# List to hold raw dataframes for cleaning
sensor_dataframes_outdoor = []

# Load each file in the raw outdoor directory
for file_name in os.listdir(raw_dir):
    file_path = os.path.join(raw_dir, file_name)
    if file_name.endswith('.csv'):
        # Read the raw data
        df = pd.read_csv(file_path)
        sensor_dataframes_outdoor.append(df)

# Apply cleaning function
cleaned_sensor_dataframes_outdoor = clean_sensor_dataframes_outdoor(sensor_dataframes_outdoor)

# Save each cleaned DataFrame to the cleaned directory
for i, cleaned_df in enumerate(cleaned_sensor_dataframes_outdoor):
    # Create filename based on the original sensor name
    cleaned_file_name = f"{sensor_names[i]}_cleaned.csv"
    cleaned_file_path = os.path.join(cleaned_dir, cleaned_file_name)
    cleaned_df.to_csv(cleaned_file_path, index=False)

print("All outdoor sensor datasets have been cleaned and saved.")
# Out:
# Columns not present in the Dataframe: []
# All outdoor sensor datasets have been cleaned and saved.
