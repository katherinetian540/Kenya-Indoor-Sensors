# %%
import os
import pandas as pd

# %% [markdown]
# ## Clean Data

# %%
# Directory containing sensor data files
data_dir = 'data/Indoor_raw'
output_dir = 'data/filtered_raw' 

# Create the filtered directory if it doesn’t exist
os.makedirs(output_dir, exist_ok=True)

# Define the date ranges for each sensor based on the data provided
sensor_time_frames = {
    'Indoor01.csv': ('2024-02-14', '2024-04-16'), 
    'Indoor02.csv': ('2024-02-20', '2024-07-23'),
    'Indoor03.csv': ('2024-02-27', '2024-07-27'),
    'Indoor04.csv': ('2024-03-04', '2024-07-14'),
    'Indoor05.csv': ('2024-03-08', '2024-08-26'),
    'Indoor06.csv': ('2024-03-23', '2024-09-06'),
    'Indoor07.csv': ('2024-04-04', '2024-08-11'),
    'Indoor08.csv': ('2024-04-23', '2024-08-20'),
    'Indoor09.csv': ('2024-04-25', '2024-08-31'),
    'Indoor10.csv': ('2024-04-30', '2024-08-30'),
    'Indoor11.csv': ('2024-05-04', '2024-09-07'),
    'Indoor12.csv': ('2024-05-04', '2024-09-15'),
    'Indoor13.csv': ('2024-05-14', '2024-08-09'),  
    'Indoor14.csv': ('2024-05-25', '2024-10-09'),
    'Indoor15.csv': ('2024-07-14', '2024-11-27') 
}

# %%
# Define the columns that need to be converted to numeric
numeric_columns = [
    'PM1.0', 'PM2.5', 'PM4.0', 'PM10',
    'PM0.5 NC', 'PM1.0 NC', 'PM2.5 NC', 'PM4.0 NC', 'PM10 NC',
    'CO2', 'Barometric Pressure', 'VOC tVOC measurement',
    'Temperature', 'Relative Humidity'
]

# Drop unnecessary columns (like calibration settings & metadata) if needed
drop_columns = [
    'Device ID', 'Serial Number', 'Model', 'Sub Model', 'Friendly Name',
    'Is Indoor', 'Is Public', 'System Status'
]

# Function to clean each sensor DataFrame
def clean_sensor_dataframe(sensor_df):
    """
    Cleans the sensor DataFrame:
    - Converts timestamps
    - Creates 'Timestamp_Local' (+3 hours)
    - Converts numeric columns
    - Drops unnecessary metadata
    """
    sensor_df = sensor_df.iloc[1:]  # Remove the second header row
    sensor_df = sensor_df.sort_values(by=['Timestamp']).reset_index(drop=True)  # Sort timestamps
    sensor_df['Timestamp'] = pd.to_datetime(sensor_df['Timestamp'], errors='coerce')  # Convert to datetime
    sensor_df['Timestamp_Local'] = sensor_df['Timestamp'] + pd.Timedelta(hours=3)  # Add 3 hours
    sensor_df[numeric_columns] = sensor_df[numeric_columns].apply(pd.to_numeric, errors='coerce')  # Convert to numeric
    sensor_df = sensor_df.drop(columns=drop_columns, errors='ignore')  # Drop unneeded columns
    return sensor_df  # ✅ RETURN the cleaned DataFrame

# Loop over each sensor file in the data directory
for file_name in os.listdir(data_dir):
    file_path = os.path.join(data_dir, file_name)
    
    # Check if the file is a CSV and in the sensor time frames dictionary
    if file_name.endswith('.csv') and file_name in sensor_time_frames:
        print(f"Processing: {file_name}")

        # Read the CSV file
        df = pd.read_csv(file_path)

        # Clean the sensor DataFrame
        df = clean_sensor_dataframe(df)  

        if df is not None:  # Ensure DataFrame is valid before filtering
            # Get the start and end date for this sensor
            start_date, end_date = sensor_time_frames[file_name]
            start_date = pd.to_datetime(start_date)

            # Apply date filtering based on the defined range
            if end_date:
                end_date = pd.to_datetime(end_date)
                filtered_df = df[(df['Timestamp_Local'] >= start_date) & (df['Timestamp_Local'] <= end_date)]
            else:
                filtered_df = df[df['Timestamp_Local'] >= start_date]

            # Save the cleaned and filtered data to the output directory
            output_file_path = os.path.join(output_dir, file_name)
            filtered_df.to_csv(output_file_path, index=False)
            print(f"Saved: {output_file_path}")
# Out:
# Processing: Indoor14.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor14.csv
# Processing: Indoor01.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor01.csv
# Processing: Indoor15.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor15.csv
# Processing: Indoor03.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor03.csv
# Processing: Indoor02.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor02.csv
# Processing: Indoor06.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor06.csv
# Processing: Indoor12.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor12.csv
# Processing: Indoor13.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor13.csv
# Processing: Indoor07.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor07.csv
# Processing: Indoor11.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor11.csv
# Processing: Indoor05.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor05.csv
# Processing: Indoor04.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor04.csv
# Processing: Indoor10.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor10.csv
# Processing: Indoor09.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor09.csv
# Processing: Indoor08.csv
# /var/folders/5r/t7s5jp8s20scm4rjflwzb5_h0000gn/T/ipykernel_31466/1863133249.py:41: DtypeWarning: Columns (8,9,12,13,16,17,20,21,22,23,24,25,27,31,35,38,42,46,50,54,58,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Saved: data/filtered_raw/Indoor08.csv

# %% [markdown]
# ## Harmonization

# %%
# Directory containing filtered sensor data files
filtered_dir = 'data/filtered_raw'  # Directory with cleaned and filtered data
harmonized_dir = 'data/harmonized'  # Directory to save harmonized data
parameters_dir = "parameters"  # Directory containing individual parameter files

# Ensure the harmonized directory exists
os.makedirs(harmonized_dir, exist_ok=True)

# Define the columns to calibrate
working_columns = ['PM2.5', 'CO2', 'Barometric Pressure', 'VOC tVOC measurement', 'Temperature', 'Relative Humidity']

# %%
# Loop through each dataset in the filtered directory
for file_name in os.listdir(filtered_dir):
    file_path = os.path.join(filtered_dir, file_name)
    
    # Process only CSV files
    if file_name.endswith('.csv'):
        # Read the filtered dataset
        sensor_df = pd.read_csv(file_path)
        
        # Use the filename (without extension) as the Sensor ID
        sensor_id = file_name.replace(".csv", "")  # e.g., 'Indoor01.csv' -> 'Indoor01'
        sensor_df['Sensor'] = sensor_id  # Add the Sensor ID to the DataFrame
        
        print(f"\nProcessing file: {file_name} with Sensor ID: {sensor_id}")

        # Loop through each column in working_columns to apply calibration
        for column_name in working_columns:
            # Prepare the path to the coefficients file
            coeff_file_name = f"{column_name.lower().replace(' ', '_')}_coefficients_df.csv"
            coefficients_file = os.path.join(parameters_dir, coeff_file_name)
            
            # Check if the coefficient file exists
            if os.path.exists(coefficients_file):
                # Read the coefficients data
                coefficients_df = pd.read_csv(coefficients_file)
                
                # Rename columns dynamically to avoid conflicts
                coefficients_df.rename(columns={'Coefficient': f'{column_name}_Coefficient',
                                                'Intercept': f'{column_name}_Intercept'}, inplace=True)
                
                # Merge the sensor DataFrame with the coefficients DataFrame
                sensor_df = pd.merge(sensor_df, coefficients_df, on='Sensor', how='left')
                
                # Check if the merge was successful by inspecting NaNs in coefficient columns
                if sensor_df[f'{column_name}_Coefficient'].isnull().all():
                    print(f"Warning: All coefficients missing for '{column_name}' in sensor '{sensor_id}'")
                else:
                    # Print out the first few rows to verify calibration before applying it
                    print(f"\nBefore calibration for '{column_name}':")
                    print(sensor_df[[column_name, f'{column_name}_Coefficient', f'{column_name}_Intercept']].head())

                    # Apply calibration formula
                    sensor_df[column_name] = sensor_df[column_name] * sensor_df[f'{column_name}_Coefficient'] + sensor_df[f'{column_name}_Intercept']
                    
                    # Check the first few calibrated values
                    print(f"\nCalibrated values for '{column_name}' in '{file_name}':")
                    print(sensor_df[[column_name]].head())
                
                # Drop coefficient and intercept columns to clean up
                sensor_df.drop(columns=[f'{column_name}_Coefficient', f'{column_name}_Intercept'], inplace=True)
            else:
                print(f"Warning: No coefficients file found for {coeff_file_name}")
        
        # Save the harmonized data to the harmonized directory
        harmonized_file_path = os.path.join(harmonized_dir, file_name)
        sensor_df.to_csv(harmonized_file_path, index=False)

print("All harmonized datasets have been saved.")
# Out:
# Processing file: Indoor14.csv with Sensor ID: Indoor14
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0  489          0.95968      20.720851
# 1  482          0.95968      20.720851
# 2  476          0.95968      20.720851
# 3  468          0.95968      20.720851
# 4  465          0.95968      20.720851
#
# Calibrated values for 'CO2' in 'Indoor14.csv':
#           CO2
# 0  490.004411
# 1  483.286650
# 2  477.528569
# 3  469.851129
# 4  466.972089
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.65                         0.987145  \
# 1                23.64                         0.987145
# 2                23.64                         0.987145
# 3                23.63                         0.987145
# 4                23.63                         0.987145
#
#    Barometric Pressure_Intercept
# 0                       0.292873
# 1                       0.292873
# 2                       0.292873
# 3                       0.292873
# 4                       0.292873
#
# Calibrated values for 'Barometric Pressure' in 'Indoor14.csv':
#    Barometric Pressure
# 0            23.638842
# 1            23.628971
# 2            23.628971
# 3            23.619099
# 4            23.619099
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.667                           1.03789  \
# 1                 0.614                           1.03789
# 2                 0.569                           1.03789
# 3                 0.474                           1.03789
# 4                 0.421                           1.03789
#
#    VOC tVOC measurement_Intercept
# 0                        0.026271
# 1                        0.026271
# 2                        0.026271
# 3                        0.026271
# 4                        0.026271
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor14.csv':
#    VOC tVOC measurement
# 0              0.718544
# 1              0.663536
# 2              0.616831
# 3              0.518231
# 4              0.463223
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         71.1                 0.986584               0.856756
# 1         71.1                 0.986584               0.856756
# 2         71.1                 0.986584               0.856756
# 3         71.1                 0.986584               0.856756
# 4         71.1                 0.986584               0.856756
#
# Calibrated values for 'Temperature' in 'Indoor14.csv':
#    Temperature
# 0    71.002912
# 1    71.002912
# 2    71.002912
# 3    71.002912
# 4    71.002912
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 63                       1.031697  \
# 1                 63                       1.031697
# 2                 63                       1.031697
# 3                 63                       1.031697
# 4                 63                       1.031697
#
#    Relative Humidity_Intercept
# 0                    -1.366351
# 1                    -1.366351
# 2                    -1.366351
# 3                    -1.366351
# 4                    -1.366351
#
# Calibrated values for 'Relative Humidity' in 'Indoor14.csv':
#    Relative Humidity
# 0          63.630582
# 1          63.630582
# 2          63.630582
# 3          63.630582
# 4          63.630582
#
# Processing file: Indoor01.csv with Sensor ID: Indoor01
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0  454          1.01035      -2.341322
# 1  454          1.01035      -2.341322
# 2  456          1.01035      -2.341322
# 3  455          1.01035      -2.341322
# 4  460          1.01035      -2.341322
#
# Calibrated values for 'CO2' in 'Indoor01.csv':
#           CO2
# 0  456.357795
# 1  456.357795
# 2  458.378496
# 3  457.368146
# 4  462.419898
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.60                         0.997538  \
# 1                23.59                         0.997538
# 2                23.59                         0.997538
# 3                23.58                         0.997538
# 4                23.57                         0.997538
#
#    Barometric Pressure_Intercept
# 0                       0.087622
# 1                       0.087622
# 2                       0.087622
# 3                       0.087622
# 4                       0.087622
#
# Calibrated values for 'Barometric Pressure' in 'Indoor01.csv':
#    Barometric Pressure
# 0            23.629513
# 1            23.619538
# 2            23.619538
# 3            23.609562
# 4            23.599587
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.367                          0.908284  \
# 1                 0.339                          0.908284
# 2                 0.328                          0.908284
# 3                 0.289                          0.908284
# 4                 0.272                          0.908284
#
#    VOC tVOC measurement_Intercept
# 0                        0.008089
# 1                        0.008089
# 2                        0.008089
# 3                        0.008089
# 4                        0.008089
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor01.csv':
#    VOC tVOC measurement
# 0              0.341429
# 1              0.315997
# 2              0.306006
# 3              0.270583
# 4              0.255142
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         74.3                 0.965395               2.461006
# 1         74.1                 0.965395               2.461006
# 2         73.9                 0.965395               2.461006
# 3         73.8                 0.965395               2.461006
# 4         73.6                 0.965395               2.461006
#
# Calibrated values for 'Temperature' in 'Indoor01.csv':
#    Temperature
# 0    74.189858
# 1    73.996779
# 2    73.803700
# 3    73.707160
# 4    73.514081
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 50                       0.969444  \
# 1                 50                       0.969444
# 2                 50                       0.969444
# 3                 50                       0.969444
# 4                 51                       0.969444
#
#    Relative Humidity_Intercept
# 0                     1.905022
# 1                     1.905022
# 2                     1.905022
# 3                     1.905022
# 4                     1.905022
#
# Calibrated values for 'Relative Humidity' in 'Indoor01.csv':
#    Relative Humidity
# 0          50.377224
# 1          50.377224
# 2          50.377224
# 3          50.377224
# 4          51.346668
#
# Processing file: Indoor15.csv with Sensor ID: Indoor15
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#      CO2  CO2_Coefficient  CO2_Intercept
# 0  15324         0.927056       35.47323
# 1  15369         0.927056       35.47323
# 2  15348         0.927056       35.47323
# 3  15380         0.927056       35.47323
# 4  15393         0.927056       35.47323
#
# Calibrated values for 'CO2' in 'Indoor15.csv':
#             CO2
# 0  14241.678754
# 1  14283.396272
# 2  14263.928097
# 3  14293.593888
# 4  14305.645615
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.66                         0.987023  \
# 1                23.66                         0.987023
# 2                23.66                         0.987023
# 3                23.65                         0.987023
# 4                23.65                         0.987023
#
#    Barometric Pressure_Intercept
# 0                       0.291402
# 1                       0.291402
# 2                       0.291402
# 3                       0.291402
# 4                       0.291402
#
# Calibrated values for 'Barometric Pressure' in 'Indoor15.csv':
#    Barometric Pressure
# 0            23.644375
# 1            23.644375
# 2            23.644375
# 3            23.634504
# 4            23.634504
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 55                       1.017823  \
# 1                 55                       1.017823
# 2                 55                       1.017823
# 3                 56                       1.017823
# 4                 56                       1.017823
#
#    Relative Humidity_Intercept
# 0                    -2.063793
# 1                    -2.063793
# 2                    -2.063793
# 3                    -2.063793
# 4                    -2.063793
#
# Calibrated values for 'Relative Humidity' in 'Indoor03.csv':
#    Relative Humidity
# 0          53.916495
# 1          53.916495
# 2          53.916495
# 3          54.934318
# 4          54.934318
#
# Processing file: Indoor02.csv with Sensor ID: Indoor02
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0  481          1.00709      -3.797409
# 1  420          1.00709      -3.797409
# 2  447          1.00709      -3.797409
# 3  437          1.00709      -3.797409
# 4  450          1.00709      -3.797409
#
# Calibrated values for 'CO2' in 'Indoor02.csv':
#           CO2
# 0  480.613080
# 1  419.180565
# 2  446.372006
# 3  436.301102
# 4  449.393277
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.55                         0.990223  \
# 1                23.55                         0.990223
# 2                23.54                         0.990223
# 3                23.53                         0.990223
# 4                23.52                         0.990223
#
#    Barometric Pressure_Intercept
# 0                       0.249064
# 1                       0.249064
# 2                       0.249064
# 3                       0.249064
# 4                       0.249064
#
# Calibrated values for 'Barometric Pressure' in 'Indoor02.csv':
#    Barometric Pressure
# 0            23.568816
# 1            23.568816
# 2            23.558913
# 3            23.549011
# 4            23.539109
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.000                          0.962169  \
# 1                 0.009                          0.962169
# 2                 0.031                          0.962169
# 3                 0.010                          0.962169
# 4                 0.014                          0.962169
#
#    VOC tVOC measurement_Intercept
# 0                        0.005709
# 1                        0.005709
# 2                        0.005709
# 3                        0.005709
# 4                        0.005709
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor02.csv':
#    VOC tVOC measurement
# 0              0.005709
# 1              0.014368
# 2              0.035536
# 3              0.015330
# 4              0.019179
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         81.7                  0.94523               3.991724
# 1         81.7                  0.94523               3.991724
# 2         81.5                  0.94523               3.991724
# 3         82.0                  0.94523               3.991724
# 4         82.0                  0.94523               3.991724
#
# Calibrated values for 'Temperature' in 'Indoor02.csv':
#    Temperature
# 0    81.217009
# 1    81.217009
# 2    81.027963
# 3    81.500578
# 4    81.500578
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 39                       0.966599  \
# 1                 38                       0.966599
# 2                 38                       0.966599
# 3                 37                       0.966599
# 4                 37                       0.966599
#
#    Relative Humidity_Intercept
# 0                     2.307922
# 1                     2.307922
# 2                     2.307922
# 3                     2.307922
# 4                     2.307922
#
# Calibrated values for 'Relative Humidity' in 'Indoor02.csv':
#    Relative Humidity
# 0          40.005295
# 1          39.038696
# 2          39.038696
# 3          38.072097
# 4          38.072097
#
# Processing file: Indoor06.csv with Sensor ID: Indoor06
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0  484         0.954395      27.491217
# 1  490         0.954395      27.491217
# 2  539         0.954395      27.491217
# 3  481         0.954395      27.491217
# 4  481         0.954395      27.491217
#
# Calibrated values for 'CO2' in 'Indoor06.csv':
#           CO2
# 0  489.418243
# 1  495.144611
# 2  541.909951
# 3  486.555059
# 4  486.555059
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         72.1                 0.913395                6.16842
# 1         72.1                 0.913395                6.16842
# 2         72.0                 0.913395                6.16842
# 3         71.8                 0.913395                6.16842
# 4         71.6                 0.913395                6.16842
#
# Calibrated values for 'Temperature' in 'Indoor12.csv':
#    Temperature
# 0    72.024211
# 1    72.024211
# 2    71.932871
# 3    71.750192
# 4    71.567513
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 68                       1.036515  \
# 1                 68                       1.036515
# 2                 68                       1.036515
# 3                 68                       1.036515
# 4                 68                       1.036515
#
#    Relative Humidity_Intercept
# 0                    -5.527539
# 1                    -5.527539
# 2                    -5.527539
# 3                    -5.527539
# 4                    -5.527539
#
# Calibrated values for 'Relative Humidity' in 'Indoor12.csv':
#    Relative Humidity
# 0          64.955499
# 1          64.955499
# 2          64.955499
# 3          64.955499
# 4          64.955499
#
# Processing file: Indoor13.csv with Sensor ID: Indoor13
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0  459         0.979905       7.638423
# 1  465         0.979905       7.638423
# 2  474         0.979905       7.638423
# 3  494         0.979905       7.638423
# 4  499         0.979905       7.638423
#
# Calibrated values for 'CO2' in 'Indoor13.csv':
#           CO2
# 0  457.414895
# 1  463.294326
# 2  472.113472
# 3  491.711576
# 4  496.611102
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.60                         0.982774  \
# 1                23.60                         0.982774
# 2                23.60                         0.982774
# 3                23.59                         0.982774
# 4                23.59                         0.982774
#
#    Barometric Pressure_Intercept
# 0                       0.392693
# 1                       0.392693
# 2                       0.392693
# 3                       0.392693
# 4                       0.392693
#
# Calibrated values for 'Barometric Pressure' in 'Indoor13.csv':
#    Barometric Pressure
# 0            23.586165
# 1            23.586165
# 2            23.586165
# 3            23.576337
# 4            23.576337
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.487                          0.952425  \
# 1                 0.497                          0.952425
# 2                 0.512                          0.952425
# 3                 0.499                          0.952425
# 4                 0.462                          0.952425
#
#    VOC tVOC measurement_Intercept
# 0                        0.014127
# 1                        0.014127
# 2                        0.014127
# 3                        0.014127
# 4                        0.014127
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor13.csv':
#    VOC tVOC measurement
# 0              0.477958
# 1              0.487482
# 2              0.501768
# 3              0.489387
# 4              0.454147
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         73.2                 1.039909              -2.825404
# 1         73.0                 1.039909              -2.825404
# 2         72.9                 1.039909              -2.825404
# 3         72.7                 1.039909              -2.825404
# 4         72.5                 1.039909              -2.825404
#
# Calibrated values for 'Temperature' in 'Indoor13.csv':
#    Temperature
# 0    73.295944
# 1    73.087962
# 2    72.983971
# 3    72.775989
# 4    72.568007
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 50                       1.009238  \
# 1                 50                       1.009238
# 2                 50                       1.009238
# 3                 51                       1.009238
# 4                 51                       1.009238
#
#    Relative Humidity_Intercept
# 0                    -0.208683
# 1                    -0.208683
# 2                    -0.208683
# 3                    -0.208683
# 4                    -0.208683
#
# Calibrated values for 'Relative Humidity' in 'Indoor13.csv':
#    Relative Humidity
# 0          50.253230
# 1          50.253230
# 2          50.253230
# 3          51.262468
# 4          51.262468
#
# Processing file: Indoor07.csv with Sensor ID: Indoor07
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#     CO2  CO2_Coefficient  CO2_Intercept
# 0  1633         0.915331      38.397817
# 1  1427         0.915331      38.397817
# 2  1231         0.915331      38.397817
# 3  1212         0.915331      38.397817
# 4  1210         0.915331      38.397817
#
# Calibrated values for 'CO2' in 'Indoor07.csv':
#            CO2
# 0  1533.133843
# 1  1344.575593
# 2  1165.170657
# 3  1147.779362
# 4  1145.948700
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor11.csv':
#    VOC tVOC measurement
# 0              0.082097
# 1              0.082097
# 2              0.075534
# 3              0.064285
# 4              0.054910
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         72.5                 1.043613              -3.376673
# 1         72.5                 1.043613              -3.376673
# 2         72.3                 1.043613              -3.376673
# 3         72.1                 1.043613              -3.376673
# 4         72.0                 1.043613              -3.376673
#
# Calibrated values for 'Temperature' in 'Indoor11.csv':
#    Temperature
# 0    72.285283
# 1    72.285283
# 2    72.076560
# 3    71.867837
# 4    71.763476
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 66                       1.014429  \
# 1                 66                       1.014429
# 2                 66                       1.014429
# 3                 66                       1.014429
# 4                 66                       1.014429
#
#    Relative Humidity_Intercept
# 0                     -1.63044
# 1                     -1.63044
# 2                     -1.63044
# 3                     -1.63044
# 4                     -1.63044
#
# Calibrated values for 'Relative Humidity' in 'Indoor11.csv':
#    Relative Humidity
# 0          65.321885
# 1          65.321885
# 2          65.321885
# 3          65.321885
# 4          65.321885
#
# Processing file: Indoor05.csv with Sensor ID: Indoor05
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0  443          1.01381      -7.277955
# 1  445          1.01381      -7.277955
# 2  446          1.01381      -7.277955
# 3  451          1.01381      -7.277955
# 4  453          1.01381      -7.277955
#
# Calibrated values for 'CO2' in 'Indoor05.csv':
#           CO2
# 0  441.839735
# 1  443.867355
# 2  444.881164
# 3  449.950213
# 4  451.977832
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.64                         0.992086  \
# 1                23.63                         0.992086
# 2                23.63                         0.992086
# 3                23.61                         0.992086
# 4                23.61                         0.992086
#
#    Barometric Pressure_Intercept
# 0                        0.19521
# 1                        0.19521
# 2                        0.19521
# 3                        0.19521
# 4                        0.19521
#
# Calibrated values for 'Barometric Pressure' in 'Indoor05.csv':
#    Barometric Pressure
# 0            23.648120
# 1            23.638200
# 2            23.638200
# 3            23.618358
# 4            23.618358
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.742                          1.004363  \
# 1                 0.815                          1.004363
# 2                 0.855                          1.004363
# 3                 0.988                          1.004363
# 4                 1.010                          1.004363
#
#    VOC tVOC measurement_Intercept
# 0                       -0.006231
# 1                       -0.006231
# 2                       -0.006231
# 3                       -0.006231
# 4                       -0.006231
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor05.csv':
#    VOC tVOC measurement
# 0              0.739006
# 1              0.812325
# 2              0.852499
# 3              0.986079
# 4              1.008175
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         75.6                  0.91173                6.14723
# 1         75.4                  0.91173                6.14723
# 2         75.2                  0.91173                6.14723
# 3         74.8                  0.91173                6.14723
# 4         74.7                  0.91173                6.14723
#
# Calibrated values for 'Temperature' in 'Indoor05.csv':
#    Temperature
# 0    75.074052
# 1    74.891706
# 2    74.709360
# 3    74.344667
# 4    74.253494
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 48                       0.980267  \
# 1                 48                       0.980267
# 2                 49                       0.980267
# 3                 49                       0.980267
# 4                 50                       0.980267
#
#    Relative Humidity_Intercept
# 0                     2.011482
# 1                     2.011482
# 2                     2.011482
# 3                     2.011482
# 4                     2.011482
#
# Calibrated values for 'Relative Humidity' in 'Indoor05.csv':
#    Relative Humidity
# 0          49.064307
# 1          49.064307
# 2          50.044574
# 3          50.044574
# 4          51.024841
#
# Processing file: Indoor04.csv with Sensor ID: Indoor04
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.129                           0.75426  \
# 1                 0.137                           0.75426
# 2                 0.142                           0.75426
# 3                 0.159                           0.75426
# 4                 0.164                           0.75426
#
#    VOC tVOC measurement_Intercept
# 0                       -0.020859
# 1                       -0.020859
# 2                       -0.020859
# 3                       -0.020859
# 4                       -0.020859
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor10.csv':
#    VOC tVOC measurement
# 0              0.076440
# 1              0.082474
# 2              0.086246
# 3              0.099068
# 4              0.102839
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         73.8                 0.997952               0.140373
# 1         73.6                 0.997952               0.140373
# 2         73.6                 0.997952               0.140373
# 3         73.4                 0.997952               0.140373
# 4         73.4                 0.997952               0.140373
#
# Calibrated values for 'Temperature' in 'Indoor10.csv':
#    Temperature
# 0    73.789212
# 1    73.589622
# 2    73.589622
# 3    73.390032
# 4    73.390032
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 59                       0.984946  \
# 1                 60                       0.984946
# 2                 60                       0.984946
# 3                 60                       0.984946
# 4                 60                       0.984946
#
#    Relative Humidity_Intercept
# 0                     1.343864
# 1                     1.343864
# 2                     1.343864
# 3                     1.343864
# 4                     1.343864
#
# Calibrated values for 'Relative Humidity' in 'Indoor10.csv':
#    Relative Humidity
# 0          59.455683
# 1          60.440629
# 2          60.440629
# 3          60.440629
# 4          60.440629
#
# Processing file: Indoor09.csv with Sensor ID: Indoor09
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0  415         0.807396      73.656881
# 1  416         0.807396      73.656881
# 2  407         0.807396      73.656881
# 3  416         0.807396      73.656881
# 4  411         0.807396      73.656881
#
# Calibrated values for 'CO2' in 'Indoor09.csv':
#           CO2
# 0  408.726198
# 1  409.533594
# 2  402.267031
# 3  409.533594
# 4  405.496614
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.59                         0.983116  \
# 1                23.59                         0.983116
# 2                23.59                         0.983116
# 3                23.58                         0.983116
# 4                23.58                         0.983116
#
#    Barometric Pressure_Intercept
# 0                       0.403921
# 1                       0.403921
# 2                       0.403921
# 3                       0.403921
# 4                       0.403921
#
# Calibrated values for 'Barometric Pressure' in 'Indoor09.csv':
#    Barometric Pressure
# 0            23.595633
# 1            23.595633
# 2            23.595633
# 3            23.585802
# 4            23.585802
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.001                          0.994709  \
# 1                 0.005                          0.994709
# 2                 0.002                          0.994709
# 3                 0.005                          0.994709
# 4                 0.003                          0.994709
#
#    VOC tVOC measurement_Intercept
# 0                        0.005496
# 1                        0.005496
# 2                        0.005496
# 3                        0.005496
# 4                        0.005496
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor09.csv':
#    VOC tVOC measurement
# 0              0.006491
# 1              0.010470
# 2              0.007486
# 3              0.010470
# 4              0.008481
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         74.3                  1.00348              -0.398989
# 1         74.3                  1.00348              -0.398989
# 2         74.1                  1.00348              -0.398989
# 3         74.1                  1.00348              -0.398989
# 4         73.9                  1.00348              -0.398989
#
# Calibrated values for 'Temperature' in 'Indoor09.csv':
#    Temperature
# 0    74.159581
# 1    74.159581
# 2    73.958885
# 3    73.958885
# 4    73.758189
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 59                       1.026145  \
# 1                 59                       1.026145
# 2                 59                       1.026145
# 3                 59                       1.026145
# 4                 59                       1.026145
#
#    Relative Humidity_Intercept
# 0                    -0.327177
# 1                    -0.327177
# 2                    -0.327177
# 3                    -0.327177
# 4                    -0.327177
#
# Calibrated values for 'Relative Humidity' in 'Indoor09.csv':
#    Relative Humidity
# 0          60.215394
# 1          60.215394
# 2          60.215394
# 3          60.215394
# 4          60.215394
#
# Processing file: Indoor08.csv with Sensor ID: Indoor08
# Warning: No coefficients file found for pm2.5_coefficients_df.csv
#
# Before calibration for 'CO2':
#    CO2  CO2_Coefficient  CO2_Intercept
# 0  429         1.027887      -8.171484
# 1  424         1.027887      -8.171484
# 2  430         1.027887      -8.171484
# 3  418         1.027887      -8.171484
# 4  419         1.027887      -8.171484
#
# Calibrated values for 'CO2' in 'Indoor08.csv':
#           CO2
# 0  432.792245
# 1  427.652808
# 2  433.820133
# 3  421.485483
# 4  422.513371
#
# Before calibration for 'Barometric Pressure':
#    Barometric Pressure  Barometric Pressure_Coefficient
# 0                23.57                         0.987958  \
# 1                23.57                         0.987958
# 2                23.56                         0.987958
# 3                23.56                         0.987958
# 4                23.55                         0.987958
#
#    Barometric Pressure_Intercept
# 0                       0.311098
# 1                       0.311098
# 2                       0.311098
# 3                       0.311098
# 4                       0.311098
#
# Calibrated values for 'Barometric Pressure' in 'Indoor08.csv':
#    Barometric Pressure
# 0            23.597258
# 1            23.597258
# 2            23.587378
# 3            23.587378
# 4            23.577499
#
# Before calibration for 'VOC tVOC measurement':
#    VOC tVOC measurement  VOC tVOC measurement_Coefficient
# 0                 0.428                          0.862304  \
# 1                 0.398                          0.862304
# 2                 0.317                          0.862304
# 3                 0.165                          0.862304
# 4                 0.136                          0.862304
#
#    VOC tVOC measurement_Intercept
# 0                       -0.013925
# 1                       -0.013925
# 2                       -0.013925
# 3                       -0.013925
# 4                       -0.013925
#
# Calibrated values for 'VOC tVOC measurement' in 'Indoor08.csv':
#    VOC tVOC measurement
# 0              0.355141
# 1              0.329272
# 2              0.259425
# 3              0.128355
# 4              0.103348
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         74.8                 0.932966               4.721146
# 1         74.7                 0.932966               4.721146
# 2         74.5                 0.932966               4.721146
# 3         74.1                 0.932966               4.721146
# 4         73.9                 0.932966               4.721146
#
# Calibrated values for 'Temperature' in 'Indoor08.csv':
#    Temperature
# 0    74.506994
# 1    74.413698
# 2    74.227105
# 3    73.853918
# 4    73.667325
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient
# 0                 57                       0.987473  \
# 1                 57                       0.987473
# 2                 57                       0.987473
# 3                 57                       0.987473
# 4                 57                       0.987473
#
#    Relative Humidity_Intercept
# 0                     1.436715
# 1                     1.436715
# 2                     1.436715
# 3                     1.436715
# 4                     1.436715
#
# Calibrated values for 'Relative Humidity' in 'Indoor08.csv':
#    Relative Humidity
# 0          57.722694
# 1          57.722694
# 2          57.722694
# 3          57.722694
# 4          57.722694
# All harmonized datasets have been saved.

# %% [markdown]
# ## Outdoor Sensors

# %%
# Directories
raw_dir = '00_data/raw_data/outdoor_raw'  
cleaned_dir = '00_data/raw_data/outdoor_cleaned'  

# Ensure the cleaned directory exists
os.makedirs(cleaned_dir, exist_ok=True)

# Sensor names for mapping
sensor_names = ['outdoor01', 'outdoor02', 'outdoor03']

# Define the cleaning function for outdoor sensors
def clean_sensor_dataframes_outdoor(sensor_dataframes):
    numeric_columns = ['PM1.0', 'PM2.5', 'PM4.0', 'PM10',
                       'NC0.5', 'NC1.0', 'NC2.5', 'NC10',
                       'Temperature', 'Relative Humidity']
    cleaned_dataframes = []
    
    # Determine which columns are present and which are missing
    columns_not_present = list(set(numeric_columns) - set(sensor_dataframes[0].columns.to_list()))
    columns_present = [x for x in numeric_columns if x not in columns_not_present]

    print(f'Columns not present in the Dataframe: {columns_not_present}')

    # Loop through each sensor DataFrame for cleaning
    for sensor_df in sensor_dataframes:
        # Remove header
        sensor_df = sensor_df.iloc[1:]
        # Sort by 'Timestamp'
        sensor_df = sensor_df.sort_values(by=['Timestamp']).reset_index(drop=True)
        # Change 'Timestamp' to date format
        sensor_df['Timestamp'] = pd.to_datetime(sensor_df['Timestamp'], errors='coerce')
        sensor_df['Timestamp_Local'] = sensor_df['Timestamp'] + pd.Timedelta(hours=3)
        # Convert specified columns to numeric
        sensor_df[columns_present] = sensor_df[columns_present].apply(pd.to_numeric, errors='coerce')
        # Append the cleaned DataFrame to the list
        cleaned_dataframes.append(sensor_df)
    
    return cleaned_dataframes

# List to hold raw dataframes for cleaning
sensor_dataframes_outdoor = []

# Load each file in the raw outdoor directory
for file_name in os.listdir(raw_dir):
    file_path = os.path.join(raw_dir, file_name)
    if file_name.endswith('.csv'):
        # Read the raw data
        df = pd.read_csv(file_path)
        sensor_dataframes_outdoor.append(df)

# Apply cleaning function
cleaned_sensor_dataframes_outdoor = clean_sensor_dataframes_outdoor(sensor_dataframes_outdoor)

# Save each cleaned DataFrame to the cleaned directory
for i, cleaned_df in enumerate(cleaned_sensor_dataframes_outdoor):
    # Create filename based on the original sensor name
    cleaned_file_name = f"{sensor_names[i]}_cleaned.csv"
    cleaned_file_path = os.path.join(cleaned_dir, cleaned_file_name)
    cleaned_df.to_csv(cleaned_file_path, index=False)

print("All outdoor sensor datasets have been cleaned and saved.")
# Out:
# Columns not present in the Dataframe: ['NC2.5', 'NC10', 'NC1.0', 'NC0.5']
# All outdoor sensor datasets have been cleaned and saved.

# %%
# Directory containing filtered sensor data files
filtered_dir = '00_data/raw_data/outdoor_cleaned'  
harmonized_dir = '00_data/calibrated_data/outdoor_cal'
parameters_dir = "02_parameters"  # Directory containing individual parameter files

# Ensure the harmonized directory exists
os.makedirs(harmonized_dir, exist_ok=True)

# Define the columns to calibrate
working_columns = ['PM2.5', 'Temperature', 'Relative Humidity']

# %%
# Loop through each dataset in the filtered directory
for file_name in os.listdir(filtered_dir):
    file_path = os.path.join(filtered_dir, file_name)
    
    # Process only CSV files
    if file_name.endswith('.csv'):
        # Read the filtered dataset
        sensor_df = pd.read_csv(file_path)
        
        # Use the filename (without extension) as the Sensor ID
        sensor_id = file_name.replace("_cleaned.csv", "")  
        sensor_df['Sensor'] = sensor_id  
        
        print(f"\nProcessing file: {file_name} with Sensor ID: {sensor_id}")

        # Loop through each column in working_columns to apply calibration
        for column_name in working_columns:
            # Prepare the path to the coefficients file
            coeff_file_name = f"outdoor_{column_name.lower().replace(' ', '_')}_parameters.csv"
            coefficients_file = os.path.join(parameters_dir, coeff_file_name)
            
            # Check if the coefficient file exists
            if os.path.exists(coefficients_file):
                # Read the coefficients data
                coefficients_df = pd.read_csv(coefficients_file)
                
                # Rename columns dynamically to avoid conflicts
                coefficients_df.rename(columns={'Coefficient': f'{column_name}_Coefficient',
                                                'Intercept': f'{column_name}_Intercept'}, inplace=True)
                
                # Merge the sensor DataFrame with the coefficients DataFrame
                sensor_df = pd.merge(sensor_df, coefficients_df, on='Sensor', how='left')
                
                # Check if the merge was successful by inspecting NaNs in coefficient columns
                if sensor_df[f'{column_name}_Coefficient'].isnull().all():
                    print(f"Warning: All coefficients missing for '{column_name}' in sensor '{sensor_id}'")
                else:
                    # Print out the first few rows to verify calibration before applying it
                    print(f"\nBefore calibration for '{column_name}':")
                    print(sensor_df[[column_name, f'{column_name}_Coefficient', f'{column_name}_Intercept']].head())

                    # Apply calibration formula
                    sensor_df[column_name] = sensor_df[column_name] * sensor_df[f'{column_name}_Coefficient'] + sensor_df[f'{column_name}_Intercept']
                    
                    # Check the first few calibrated values
                    print(f"\nCalibrated values for '{column_name}' in '{file_name}':")
                    print(sensor_df[[column_name]].head())
                
                # Drop coefficient and intercept columns to clean up
                sensor_df.drop(columns=[f'{column_name}_Coefficient', f'{column_name}_Intercept'], inplace=True)
            else:
                print(f"Warning: No coefficients file found for {coeff_file_name}")
        
        # Save the harmonized data to the harmonized directory
        harmonized_file_path = os.path.join(harmonized_dir, file_name)
        sensor_df.to_csv(harmonized_file_path, index=False)

print("All harmonized datasets have been saved.")
# Out:
# Processing file: outdoor03_cleaned.csv with Sensor ID: outdoor03
#
# Before calibration for 'PM2.5':
#    PM2.5  PM2.5_Coefficient  PM2.5_Intercept
# 0      1           0.690358        18.614914
# 1      1           0.690358        18.614914
# 2      1           0.690358        18.614914
# 3      1           0.690358        18.614914
# 4      1           0.690358        18.614914
#
# Calibrated values for 'PM2.5' in 'outdoor03_cleaned.csv':
#        PM2.5
# 0  19.305271
# 1  19.305271
# 2  19.305271
# 3  19.305271
# 4  19.305271
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         73.0                 0.972709               1.840858
# 1         73.0                 0.972709               1.840858
# 2         73.2                 0.972709               1.840858
# 3         73.2                 0.972709               1.840858
# 4         73.2                 0.972709               1.840858
#
# Calibrated values for 'Temperature' in 'outdoor03_cleaned.csv':
#    Temperature
# 0    72.848591
# 1    72.848591
# 2    73.043133
# 3    73.043133
# 4    73.043133
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient  \
# 0                 49                        0.90407
# 1                 49                        0.90407
# 2                 49                        0.90407
# 3                 49                        0.90407
# 4                 49                        0.90407
#
#    Relative Humidity_Intercept
# 0                     6.692494
# 1                     6.692494
# 2                     6.692494
# 3                     6.692494
# 4                     6.692494
#
# Calibrated values for 'Relative Humidity' in 'outdoor03_cleaned.csv':
#    Relative Humidity
# 0          50.991921
# 1          50.991921
# 2          50.991921
# 3          50.991921
# 4          50.991921
#
# Processing file: outdoor01_cleaned.csv with Sensor ID: outdoor01
#
# Before calibration for 'PM2.5':
#    PM2.5  PM2.5_Coefficient  PM2.5_Intercept
# 0      1           0.633213        18.348676
# 1      1           0.633213        18.348676
# 2      1           0.633213        18.348676
# 3      1           0.633213        18.348676
# 4      1           0.633213        18.348676
#
# Calibrated values for 'PM2.5' in 'outdoor01_cleaned.csv':
#        PM2.5
# 0  18.981889
# 1  18.981889
# 2  18.981889
# 3  18.981889
# 4  18.981889
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         75.2                 0.638316               24.08289
# 1         75.2                 0.638316               24.08289
# 2         75.2                 0.638316               24.08289
# 3         75.4                 0.638316               24.08289
# 4         75.2                 0.638316               24.08289
#
# Calibrated values for 'Temperature' in 'outdoor01_cleaned.csv':
#    Temperature
# 0    72.084270
# 1    72.084270
# 2    72.084270
# 3    72.211933
# 4    72.084270
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient  \
# 0                 46                       0.627146
# 1                 46                       0.627146
# 2                 46                       0.627146
# 3                 46                       0.627146
# 4                 46                       0.627146
#
#    Relative Humidity_Intercept
# 0                     27.10595
# 1                     27.10595
# 2                     27.10595
# 3                     27.10595
# 4                     27.10595
#
# Calibrated values for 'Relative Humidity' in 'outdoor01_cleaned.csv':
#    Relative Humidity
# 0          55.954684
# 1          55.954684
# 2          55.954684
# 3          55.954684
# 4          55.954684
#
# Processing file: outdoor02_cleaned.csv with Sensor ID: outdoor02
#
# Before calibration for 'PM2.5':
#    PM2.5  PM2.5_Coefficient  PM2.5_Intercept
# 0      4           0.263355        17.595987
# 1      4           0.263355        17.595987
# 2      3           0.263355        17.595987
# 3      3           0.263355        17.595987
# 4      3           0.263355        17.595987
#
# Calibrated values for 'PM2.5' in 'outdoor02_cleaned.csv':
#        PM2.5
# 0  18.649406
# 1  18.649406
# 2  18.386052
# 3  18.386052
# 4  18.386052
#
# Before calibration for 'Temperature':
#    Temperature  Temperature_Coefficient  Temperature_Intercept
# 0         72.9                 0.757651              16.159817
# 1         72.9                 0.757651              16.159817
# 2         72.9                 0.757651              16.159817
# 3         72.9                 0.757651              16.159817
# 4         73.0                 0.757651              16.159817
#
# Calibrated values for 'Temperature' in 'outdoor02_cleaned.csv':
#    Temperature
# 0    71.392553
# 1    71.392553
# 2    71.392553
# 3    71.392553
# 4    71.468319
#
# Before calibration for 'Relative Humidity':
#    Relative Humidity  Relative Humidity_Coefficient  \
# 0                 49                       0.917762
# 1                 49                       0.917762
# 2                 49                       0.917762
# 3                 49                       0.917762
# 4                 49                       0.917762
#
#    Relative Humidity_Intercept
# 0                     7.586873
# 1                     7.586873
# 2                     7.586873
# 3                     7.586873
# 4                     7.586873
#
# Calibrated values for 'Relative Humidity' in 'outdoor02_cleaned.csv':
#    Relative Humidity
# 0          52.557192
# 1          52.557192
# 2          52.557192
# 3          52.557192
# 4          52.557192
# All harmonized datasets have been saved.
